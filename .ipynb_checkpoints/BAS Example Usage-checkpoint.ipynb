# %%
from BAS import hroot
from BAS import connected_influences
from BAS import connected_influences_poset

for J in connected_influences(5, hroot(5), -hroot(5)):
    print(J)
# Out:
# {3, 4}
# {2}
# {2, 3, 4}
# {2, 3}
# {3}
# {1}
# {5}
# {4}

# %%
# The poset of influences of BAS for lambda=hroot and mu=alpha_1-alpha_2-3alpha_3-2alpha_4-alpha_5
connected_influences_poset(5, hroot(5), [1,-1,-3,-2,-1])
# Out:
# Finite poset containing 9 elements
