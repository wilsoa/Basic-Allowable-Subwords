# %%
from BAS import hroot
from BAS import connected_influences
from BAS import connected_influences_poset
from BAS import connected_influences_graph

# %%
# Lists the connected influences of BAS for rank 5,
# lambda=hroot, mu=-hroot
for J in connected_influences(5, hroot(5), -hroot(5)):
    print(J)
# Out:
# {3, 4}
# {2}
# {2, 3, 4}
# {2, 3}
# {3}
# {1}
# {5}
# {4}

# %%
G = connected_influences_graph(5, hroot(5), -hroot(5))

show(G)
show(G.complement())
# Out:
# Graphics object consisting of 29 graphics primitives
# Graphics object consisting of 17 graphics primitives

# %%
# The poset of influences of BAS for rank 5,
# lambda=hroot and mu=alpha_1-alpha_2-3alpha_3-2alpha_4-alpha_5
connected_influences_poset(5, [5,4,3,2,1], [-1,-1,-1,-1,-1]).plot()
# Out:
# Graphics object consisting of 23 graphics primitives
